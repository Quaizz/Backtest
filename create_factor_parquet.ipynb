# %%
from FactorCalculator import RelativeStrengthCalculator
from factor_tools import process_factors, examine_factor_file

if __name__ == "__main__":
    # Initialize factor calculators
    factors = [
        RelativeStrengthCalculator(126),  # 6-month momentum
        RelativeStrengthCalculator(252)   # 12-month momentum
    ]
    
    # Process factors
    start_date = "2020-01-01"
    end_date = "2020-12-31"
    output_folder = "factor_data"
    
    process_factors(start_date, end_date, output_folder, factors)
    
    # Examine results
    examine_factor_file("2020-01-03", "relative_strength_126d")
# Out:
# Processing 253 trading dates
#
# Processing date: 2020-01-02
# Universe size: 5225 stocks
#
# relative_strength_126d Summary for 2020-01-02:
# Total stocks in universe: 5225
# Stocks with valid factor: 5221
# Coverage ratio: 99.92%
#
# Factor Distribution:
# count    5221.000000
# mean        0.500000
# std         0.288758
# min         0.000000
# 5%          0.050000
# 25%         0.250000
# 50%         0.500000
# 75%         0.750000
# 95%         0.950000
# max         1.000000
# Name: relative_strength_126d, dtype: float64
#
# relative_strength_252d Summary for 2020-01-02:
# Total stocks in universe: 5225
# Stocks with valid factor: 5222
# Coverage ratio: 99.94%
#
# Factor Distribution:
# count    5222.000000
# mean        0.500000
# std         0.288758
# min         0.000000
# 5%          0.050000
# 25%         0.250000
# 50%         0.500000
# 75%         0.750000
# 95%         0.950000
# max         1.000000
# Name: relative_strength_252d, dtype: float64
#
# ...
